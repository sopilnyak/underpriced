# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import KFold
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('flats_features.csv')

# %%
X = df.drop({'price'}, axis=1)
Y = df['price']
X.set_index(X['id'], inplace=True)
X = X.drop('id', axis=1)

# %%
records_count = Y.count()
kf = KFold(n=records_count, n_folds=7, shuffle=True, random_state=42)

for k in range(1, 75, 2):
    clf = RandomForestRegressor(n_estimators=k, random_state=0)
    quality = cross_val_score(clf, X, Y, scoring='r2', cv=kf).mean()
    print (k, quality)
# Out:
# 1 0.73101160452
# 3 0.817924996731
# 5 0.837341816297
# 7 0.842190501307
# 9 0.844217131488
# 11 0.848141340488
# 13 0.848809459233
# 15 0.850567449424
# 17 0.851057965246
# 19 0.851885088716
# 21 0.853253508189
# 23 0.85413100133
# 25 0.854452277583
# 27 0.855231175176
# 29 0.856498491269
# 31 0.856820353712
# 33 0.856833165936
# 35 0.856827187427
# 37 0.85712404945
# 39 0.856914234498
# 41 0.857066924134
# 43 0.857390601585
# 45 0.85743561009
# 47 0.857408363676
# 49 0.857745662672
# 51 0.857616391584
# 53 0.857545239669
# 55 0.857573382665
# 57 0.857858607974
# 59 0.857827542369
# 61 0.858033111067
# 63 0.858169983219
# 65 0.858438320873
# 67 0.858412276599
# 69 0.858503761605
# 71 0.858900960252
# 73 0.85906458944

# %%
clf = RandomForestRegressor(n_estimators=73, random_state=42)
clf.fit(X, Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=73, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
features = X.columns.values
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]

indices = indices[:10]
for i in range(0, len(indices)):
    print(str(features[indices[i]]) + " " + str(importances[indices[i]]))
# Out:
# index 0.802349374935
# area 0.155785095022
# total_floor 0.00800506287623
# living_area 0.00501798861488
# id 0.0029108940069
# underground=щукинская 0.00247128997268
# kitchen_area 0.00193358152997
# has_loggia 0.00190922731792
# combined_bathroom_count 0.00181677589114
# is_center 0.00152502396922

# %%
predictions = pd.DataFrame(clf.predict(X))[0]
X = X.reset_index()

# %%
res_info = pd.DataFrame(columns=[u'Ошибка,%',u'Ошибка,$',u'Цена м.кв.'])
for i in Y.index:
    error = (Y[i] - predictions[i])
    rel_error = error/predictions[i]*100
    res_info.loc[i] = pd.Series({
            u'Ошибка,%':round(rel_error,1),
            u'Ошибка,$':int(error),
            u'Цена м.кв.':int(Y[i] / X['area'][i])
    })

# %%
predictions = pd.DataFrame(predictions)

# %%
predictions = predictions.set_index(X['id'])

# %%
res_info = res_info.set_index(X['id'])

# %%
res_info
# Out:
#            Ошибка,%  Ошибка,$  Цена м.кв.
# id
# 158139251     -33.5  -14082.0      1555.0
# 165841067       5.2    2945.0      1714.0
# 165361751      18.1   17602.0      1575.0
# 164117640      10.9   13794.0      1428.0
# 165863255     -44.6  -14465.0       473.0
# 164709012     -21.7   -5000.0       600.0
# 164698394      -7.1   -6506.0       696.0
# 165858655      -4.4   -3643.0      1454.0
# 164196724      -6.3   -5356.0      1000.0
# 166018225      -2.5   -2054.0      1818.0
# 164544906      -4.4   -3671.0       851.0
# 165503427      -0.3    -219.0      1440.0
# 165797607       9.2   16041.0      1172.0
# 151912959       5.3    5000.0      1428.0
# 159714441       5.9    5589.0      1639.0
# 165798811      10.6   18219.0      1151.0
# 164353346      14.8   24520.0      1117.0
# 163781069       2.6    2561.0       909.0
# 163925408      -1.2    -999.0       944.0
# 164022185       6.0    5684.0      1639.0
# 163744750       3.3    3356.0      1071.0
# 164857179      -3.5   -2876.0      1000.0
# 164044431       3.6    2945.0      1734.0
# 161331858      -2.6   -2232.0       876.0
# 165718690      -2.1   -1712.0      1600.0
# 157688778      -4.7   -4178.0       708.0
# 161197783      -5.3   -4452.0       761.0
# 165648230      -2.2   -1780.0      1000.0
# 164937883      -2.3   -2397.0       769.0
# 163828377      29.0   44931.0      1538.0
# ...             ...       ...         ...
# 163556770       0.0       0.0      1300.0
# 152012471      -0.1    -178.0      1777.0
# 149297690      -0.3    -547.0      2000.0
# 163557128      -0.2    -301.0      1777.0
# 148731825      -0.3    -452.0       796.0
# 163641979       2.4    3904.0      1478.0
# 164013713      -0.7   -1123.0      1333.0
# 160083530      -0.3    -547.0      2000.0
# 30830957       -0.2    -356.0      1391.0
# 163726762      -0.1    -136.0      1221.0
# 162940691      -0.2    -246.0      1454.0
# 163159099       0.9    1506.0      2750.0
# 160045989       0.5     849.0      2750.0
# 164209617       1.0    1712.0      1269.0
# 158773437       1.2    1986.0      1650.0
# 160605953      -0.4    -616.0      2285.0
# 165443820      -0.2    -397.0      2191.0
# 162082276      -0.2    -315.0      1333.0
# 165721063       1.3    2205.0      1570.0
# 163929377      -0.2    -315.0      1142.0
# 164488901      -0.2    -328.0      1185.0
# 157166906       0.0       0.0      1212.0
# 163059816      -0.3    -547.0      1739.0
# 165972446      -0.4    -602.0      1185.0
# 165147955      -0.3    -452.0       975.0
# 163325241      -0.3    -410.0      1720.0
# 158738529      -0.2    -260.0       615.0
# 157164995      -0.1    -136.0      1777.0
# 154265184      -0.2    -273.0      3018.0
# 160128723       0.7    1164.0      2171.0
#
# [3643 rows x 3 columns]

# %%
res_info.sort_values(by=u'Ошибка,%')[:5]
# Out:
#            Ошибка,%  Ошибка,$  Цена м.кв.
# id
# 165999010     -49.9  -16959.0       849.0
# 165842779     -48.4   -9369.0       333.0
# 165863255     -44.6  -14465.0       473.0
# 165979243     -41.0  -11808.0       425.0
# 158139251     -33.5  -14082.0      1555.0

# %%
res_info.sort_values(by=u'Ошибка,%', ascending=False)[:5]
# Out:
#            Ошибка,%  Ошибка,$  Цена м.кв.
# id
# 163828377      29.0   44931.0      1538.0
# 164665343      28.9   11219.0      1428.0
# 163556579      25.8   40949.0      2498.0
# 163557679      24.6   16780.0      1666.0
# 163557812      23.1   33602.0       716.0

# %%
X.set_index(X['id'], inplace=True)
X = X.drop('id', axis=1)

# %%
X.loc[163828377]
# Out:
# level_0                             29.000000
# index                               29.000000
# area                               130.000000
# combined_bathroom_count              2.000000
# construction_year                 2007.000000
# kitchen_area                        12.969304
# living_area                         54.743862
# rooms                                4.000000
# has_balcony                          0.000000
# has_loggia                           1.000000
# curr_floor                          15.000000
# total_floor                         15.000000
# is_center                            0.000000
# underground=авиамоторная             0.000000
# underground=автозаводская            0.000000
# underground=академическая            0.000000
# underground=алексеевская             0.000000
# underground=алма-атинская            0.000000
# underground=алтуфьево                0.000000
# underground=андроновка               0.000000
# underground=аннино                   0.000000
# underground=арбатская                0.000000
# underground=аэропорт                 0.000000
# underground=бабушкинская             0.000000
# underground=багратионовская          0.000000
# underground=балтийская               0.000000
# underground=баррикадная              0.000000
# underground=бауманская               0.000000
# underground=беговая                  0.000000
# underground=белокаменная             0.000000
#                                      ...
# underground=цветной бульвар          0.000000
# underground=черкизовская             0.000000
# underground=чертановская             0.000000
# underground=чеховская                0.000000
# underground=чистые пруды             0.000000
# underground=чкаловская               0.000000
# underground=шаболовская              0.000000
# underground=шелепиха                 0.000000
# underground=шипиловская              0.000000
# underground=шоссе энтузиастов        0.000000
# underground=щелковская               0.000000
# underground=щукинская                0.000000
# underground=электрозаводская         0.000000
# underground=юго-западная             0.000000
# underground=южная                    0.000000
# underground=ясенево                  0.000000
# house_type=блочный                   0.000000
# house_type=деревянный                0.000000
# house_type=кирпично-монолитный       0.000000
# house_type=кирпичный                 1.000000
# house_type=монолитный                0.000000
# house_type=не указано                0.000000
# house_type=панельный                 0.000000
# house_type=сталинский                0.000000
# house_type=старый фонд               0.000000
# repair=дизайнерский                  0.000000
# repair=евроремонт                    1.000000
# repair=косметический                 0.000000
# repair=не указано                    0.000000
# repair=отсутствует                   0.000000
# Name: 163828377, Length: 229, dtype: float64

# %%
predictions = predictions[0].map(lambda x: int(x))

# %%
predictions.to_csv('real_prices.csv')

# %%
predictions
# Out:
# id
# 158139251     42082
# 165841067     57054
# 165361751     97397
# 164117640    126205
# 165863255     32465
# 164709012     23000
# 164698394     91506
# 165858655     83643
# 164196724     85356
# 166018225     82054
# 164544906     83671
# 165503427     85219
# 165797607    173958
# 151912959     94999
# 159714441     94410
# 165798811    171780
# 164353346    165479
# 163781069     97438
# 163925408     85999
# 164022185     94315
# 163744750    101643
# 164857179     82876
# 164044431     82054
# 161331858     87232
# 165718690     81712
# 157688778     89178
# 161197783     84452
# 165648230     81780
# 164937883    102397
# 163828377    155068
#               ...
# 163556770    160000
# 152012471    160178
# 149297690    160547
# 163557128    160301
# 148731825    160452
# 163641979    166095
# 164013713    161123
# 160083530    160547
# 30830957     160356
# 163726762    160136
# 162940691    160246
# 163159099    163493
# 160045989    164150
# 164209617    163287
# 158773437    163013
# 160605953    160616
# 165443820    160397
# 162082276    160315
# 165721063    165794
# 163929377    160315
# 164488901    160328
# 157166906    160000
# 163059816    160547
# 165972446    160602
# 165147955    160452
# 163325241    160410
# 158738529    160260
# 157164995    160136
# 154265184    160273
# 160128723    163835
# Name: 0, Length: 3643, dtype: int64
